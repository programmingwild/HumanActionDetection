# %% [markdown]
# # ActionScope on Colab
# Free GPU demo of the Human Action Detection app.
#
# **Steps:** 1. (Optional, faster) Runtime → Change runtime type → T4 GPU.
# 2. Runtime → **Run all**. 3. Wait ~6 min, copy the `gradio.live` link from the last cell.
# The link stays alive while this session runs.

# %%
# !git clone https://github.com/programmingwild/HumanActionDetection.git
# %cd HumanActionDetection
# !git lfs pull
# !ls -la checkpoints/

# %%
# !pip install -q ultralytics gradio scikit-learn matplotlib pandas "numpy<2"

# %%
# !python -m src.app --port 7860 --share
